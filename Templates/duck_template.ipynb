# %% [markdown]
# <H1>Floating Duck Problem</H1>
#
# At what depth does a duck float in water? We can model a duck as a sphere with radius 10 cm and density, ρ= 0.3g/cm3  (about 1/3 the density of water).
#
# What is the duck's total mass?

# %%
mass =

# %% [markdown]
# Use the following formulas and constants:
#
# The volume of a sphere with radius r is $$V = \frac{4}{3} \pi r^3$$.
#
# If a sphere with radius r is submerged in water to a depth d, the volume of the sphere below the water line is
#
# $$\text{volume} = \frac{\pi}{3}(3rd^2 - d^3)$$
#
# as long as d < 2r
#
# An object floats at the level where the weight of the displaced water equals the total weight of the object, or equivalently, where their mass are equal.
# Write an equation for the difference in mass between the duck and displaced water. Our goal is to find values of d that are roots of this equation (ie that make this difference zero), when the duck floats.
#
# To find the root, what method should we use? Can we bracket the root? Do we have a good way to estimate the value?

# %% [markdown]
# ## Import Libraries

# %%
from numpy import pi
from scipy.optimize import brentq, newton

# %% [markdown]
# ## Define the Duck Floating Error Function
#
# This function returns the difference between the weight of the duck and the weight of the water displaced. The duck floats when this returns a zero.

# %%
def duckfloat(d):
    """
    Returns  the difference between the weight of the duck and the
    weight of the water displaced by the duck when it sinks a depth d into
    the water. The duck floats when the difference=0 
    that is, when the weight
    of the duck equals the weight of the water displaced.

    The duck is approximated by a sphere of radius r and a density
    of rhoduck (specified in the main function)

    d is the depth the bottom of the sphere (duck) sinks below the water
    surface.

    Note that values are unrealistic for d>2*r (ie fully submerged)
    """

    # weight of displaced water assuming density=1 g/cm**3
    Wwater = 

    # weight of the duck
    Wduck = 

    # difference between weights, equal to zero when duck is floating
    difference = 

    return difference

# %% [markdown]
# ## Example 1: Standard 10 cm Duck
#
# Find the floating depth for a duck with radius 10 cm and density 0.3 g/cm³

# %%
rhoduck = 
r = 
h =

print("A", r, "cm duck sinks to a depth of", round(h, 2), "cm")

# %% [markdown]
# ## Example 2: Different Sized Ducks
#
# Test how the floating depth varies with different duck sizes (keeping density constant at 0.3 g/cm³)

# %%
print('Try some different sized ducks:')

for r in [3, 5, 7, 10]:
    
    print("A", r, "cm duck sinks to a depth of", round(h, 2), "cm")

# %% [markdown]
# ## Example 3: Different Density Ducks
#
# Test how the floating depth varies with different duck densities (keeping radius constant at 10 cm)

# %%
# Radius of duck
r = 10  # cm

print('Try some different density ducks:')
